# %%
import pandas as pd

# %%
df=pd.read_csv("onlinefoods.csv")

# %%
df
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
# Histogram
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("onlinefoods.csv")

plt.hist(df['Pin code'])
plt.xlabel('Pin code')
plt.ylabel('Frequency')
plt.title('Distribution of Pin code')
plt.show()

# %%
# Pie chart
import matplotlib.pyplot as plt
df['Marital Status'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# prompt: pie chart

import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("onlinefoods.csv")

# Pie chart
df['Monthly Income'].value_counts().plot(kind='pie')
plt.title('Monthly Income Distribution')
plt.show()

# %%
# prompt: line

import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("onlinefoods.csv")

# Line chart
plt.plot(df['latitude'], df['longitude'])
plt.xlabel('latitude')
plt.ylabel('longitude')
plt.title('latitude vs logitude')
plt.show()

# %%
# prompt: scatter plot

# Scatter plot
plt.scatter(df['Age'], df['Monthly Income'])
plt.xlabel('Age')
plt.ylabel('Monthly Income')
plt.title('Age vs Monthly Income')
plt.show()

# %%
# prompt: multi-series

import pandas as pd
import matplotlib.pyplot as plt

# Sample data (replace with your actual data)
data = {
    'Year': [2010, 2011, 2012, 2013, 2014],
    'Sales_A': [100, 120, 150, 130, 160],
    'Sales_B': [80, 90, 110, 100, 120]
}
df = pd.DataFrame(data)

# Multi-series line chart
plt.plot(df['Year'], df['Sales_A'], label='Sales A')
plt.plot(df['Year'], df['Sales_B'], label='Sales B')

plt.xlabel('Year')
plt.ylabel('Sales')
plt.title('Sales Trend Over Time')
plt.legend()
plt.show()

# %%
# prompt: Using dataframe df: pie chart

import altair as alt
alt.Chart(df).mark_arc().encode(
    theta=alt.Theta(field="Age", type="quantitative"),
    color=alt.Color(field="Gender", type="nominal"),
)
# Out:
# alt.Chart(...)
